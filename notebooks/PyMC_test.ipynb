# %%
# %matplotlib inline
import numpy as np
import pymc3 as pm
import pandas as pd
#import seaborn as sns
#sns.set(color_codes=True)

np.random.seed(20090425)

# %%
drug = (101,100,102,104,102,97,105,105,98,101,100,123,105,103,100,95,102,106,
        109,102,82,102,100,102,102,101,102,102,103,103,97,97,103,101,97,104,
        96,103,124,101,101,100,101,101,104,100,101)
placebo = (99,101,100,101,102,100,97,101,104,101,102,102,100,105,88,101,100,
           104,100,100,100,101,102,103,97,101,101,100,101,99,101,100,100,
           101,100,99,101,100,102,99,100,99)

y1 = np.array(drug)
y2 = np.array(placebo)
y = pd.DataFrame(dict(value=np.r_[y1, y2], group=np.r_[['drug']*len(drug), ['placebo']*len(placebo)]))

y.hist('value', by='group');

# %%
mu_m = y.value.mean()
mu_s = y.value.std() * 2

with pm.Model() as model:

    group1_mean = pm.Normal('group1_mean', mu_m, sd=mu_s)
    group2_mean = pm.Normal('group2_mean', mu_m, sd=mu_s)

# %%
sigma_low = 1
sigma_high = 10

with model:

    group1_std = pm.Uniform('group1_std', lower=sigma_low, upper=sigma_high)
    group2_std = pm.Uniform('group2_std', lower=sigma_low, upper=sigma_high)
# Out:
# Applied interval-transform to group1_std and added transformed group1_std_interval_ to model.
# Applied interval-transform to group2_std and added transformed group2_std_interval_ to model.

# %%
with model:

    v = pm.Exponential('ν_minus_one', 1/29.) + 1
    lambda1 = group1_std**-2
    lambda2 = group2_std**-2

    group1 = pm.StudentT('drug', nu=v, mu=group1_mean, lam=lambda1, observed=y1)
    group2 = pm.StudentT('placebo', nu=v, mu=group2_mean, lam=lambda2, observed=y2)
# Out:
# Applied log-transform to ν_minus_one and added transformed ν_minus_one_log_ to model.

# %%
with model:
    trace = pm.sample(2000, njobs=2)
# Out:
# Assigned NUTS to group1_mean
# Assigned NUTS to group2_mean
# Assigned NUTS to group1_std_interval_
# Assigned NUTS to group2_std_interval_
# Assigned NUTS to ν_minus_one_log_
#  [-----------------100%-----------------] 2000 of 2000 complete in 24.4 sec

# %%
pm.plot_posterior(trace[1000:],
                  varnames=['group1_mean', 'group2_mean', 'group1_std', 'group2_std', 'v_minus_one'],
                  color='#87ceeb');
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-e3dd77586ba6> in <module>()
#       1 pm.plot_posterior(trace[1000:],
#       2                   varnames=['group1_mean', 'group2_mean', 'group1_std', 'group2_std', 'v_minus_one'],
# ----> 3                   color='#87ceeb');
#
# /usr/local/lib/python2.7/dist-packages/pymc3/plots.pyc in plot_posterior(trace, varnames, transform, figsize, alpha_level, round_to, point_estimate, rope, ref_val, kde_plot, plot_transformed, ax, **kwargs)
#     754
#     755         for a, v in zip(ax, varnames):
# --> 756             tr_values = transform(trace.get_values(v, combine=True, squeeze=True))
#     757             plot_posterior_op(tr_values, ax=a)
#     758             a.set_title(v)
#
# /usr/local/lib/python2.7/dist-packages/pymc3/backends/base.pyc in get_values(self, varname, burn, thin, combine, chains, squeeze)
# ...
